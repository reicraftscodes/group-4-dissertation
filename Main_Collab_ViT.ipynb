# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Dissertation/
# Out:
# /content/drive/MyDrive/Dissertation

# %%
# !ls
# Out:
# 'colab tutorial.pdf'   demo_multimodal.py   __pycache__		 train.py
# 'Collab Run.ipynb'     evaluate.py	    quick_inference.py	 utils.py
#  Data		       experiments	    README.md
#  dataset.py	       inference.py	    requirements.txt
#  Data.zip	       model.py		    test_inference.py

# %%
# Do not unzip again if you already unzipped it
# !unzip Data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Data/ThermalAug/T_Sad_2140_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2140_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2140_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2140_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2141_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2141_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2141_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2141_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2142_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2142_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2142_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2142_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2143_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2143_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2143_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2143_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2144_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2144_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2144_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2144_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2145_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2145_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2145_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2145_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2146_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2146_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2146_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2146_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2147_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2147_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2147_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2147_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2148_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2148_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2148_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2148_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2149_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2149_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2149_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2149_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2150_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2150_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2150_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2150_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2151_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2151_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2151_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2151_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2152_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2152_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2152_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2152_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2153_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2153_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2153_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2153_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2154_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2154_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2154_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2154_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2155_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2155_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2155_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2155_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2156_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2156_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2156_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2156_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2157_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2157_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2157_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2157_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2158_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2158_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2158_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2158_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2159_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2159_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2159_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2159_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2160_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2160_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2160_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2160_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2161_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2161_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2161_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2161_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2162_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2162_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2162_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2162_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2163_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2163_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2163_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2163_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2164_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2164_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2164_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2164_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2165_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2165_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2165_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2165_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2166_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2166_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2166_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2166_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2167_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2167_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2167_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2167_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2168_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2168_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2168_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2168_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2169_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2169_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2169_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2169_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2170_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2170_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2170_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2170_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2171_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2171_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2171_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2171_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2172_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2172_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2172_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2172_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2173_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2173_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2173_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2173_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2174_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2174_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2174_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2174_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2175_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2175_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2175_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2175_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2176_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2176_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2176_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2176_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2177_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2177_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2177_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2177_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2178_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2178_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2178_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2178_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2179_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2179_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2179_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2179_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2180_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2180_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2180_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2180_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2181_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2181_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2181_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2181_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2182_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2182_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2182_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2182_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2183_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2183_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2183_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2183_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2184_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2184_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2184_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2184_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2185_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2185_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2185_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2185_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2186_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2186_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2186_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2186_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2187_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2187_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2187_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2187_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2188_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2188_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2188_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2188_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2189_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2189_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2189_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2189_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2190_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2190_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2190_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2190_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2191_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2191_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2191_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2191_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2192_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2192_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2192_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2192_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2193_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2193_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2193_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2193_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2194_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2194_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2194_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2194_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2195_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2195_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2195_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2195_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2196_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2196_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2196_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2196_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2197_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2197_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2197_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2197_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2198_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2198_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2198_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2198_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2199_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2199_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2199_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2199_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2200_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2200_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2200_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2200_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2201_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2201_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2201_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2201_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2202_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2202_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2202_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2202_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2203_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2203_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2203_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2203_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2204_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2204_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2204_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2204_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2205_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2205_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2205_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2205_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2206_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2206_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2206_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2206_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2207_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2207_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2207_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2207_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2208_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2208_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2208_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2208_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2209_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2209_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2209_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2209_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2210_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2210_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2210_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2210_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2211_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2211_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2211_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2211_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2212_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2212_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2212_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2212_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2213_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2213_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2213_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2213_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2214_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2214_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2214_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2214_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2215_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2215_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2215_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2215_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2216_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2216_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2216_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2216_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2217_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2217_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2217_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2217_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2218_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2218_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2218_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2218_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2219_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2219_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2219_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2219_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2220_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2220_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2220_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2220_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2221_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2221_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2221_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2221_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2222_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2222_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2222_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2222_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2223_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2223_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2223_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2223_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2224_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2224_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2224_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2224_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2225_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2225_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2225_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2225_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2226_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2226_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2226_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2226_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2227_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2227_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2227_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2227_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2228_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2228_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2228_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2228_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2229_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2229_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2229_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2229_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2230_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2230_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2230_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2230_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2231_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2231_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2231_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2231_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2232_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2232_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2232_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2232_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2233_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2233_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2233_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2233_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2234_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2234_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2234_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2234_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2235_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2235_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2235_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2235_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2236_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2236_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2236_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2236_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2237_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2237_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2237_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2237_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2238_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2238_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2238_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2238_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2239_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2239_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2239_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2239_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2240_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2240_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2240_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2240_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2241_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2241_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2241_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2241_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2242_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2242_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2242_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2242_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2243_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2243_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2243_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2243_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2244_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2244_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2244_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2244_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2245_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2245_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2245_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2245_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2246_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2246_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2246_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2246_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2247_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2247_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2247_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2247_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2248_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2248_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2248_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2248_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2249_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2249_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2249_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2249_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2250_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2250_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2250_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2250_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2251_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2251_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2251_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2251_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2252_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2252_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2252_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2252_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2253_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2253_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2253_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2253_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2254_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2254_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2254_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2254_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2255_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2255_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2255_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2255_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2256_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2256_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2256_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2256_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2257_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2257_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2257_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2257_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2258_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2258_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2258_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2258_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2259_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2259_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2259_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2259_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2260_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2260_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2260_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2260_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2261_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2261_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2261_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2261_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2262_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2262_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2262_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2262_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2263_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2263_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2263_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2263_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2264_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2264_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2264_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2264_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2265_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2265_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2265_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2265_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2266_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2266_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2266_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2266_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2267_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2267_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2267_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2267_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2268_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2268_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2268_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2268_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2269_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2269_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2269_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2269_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2270_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2270_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2270_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2270_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2271_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2271_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2271_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2271_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2272_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2272_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2272_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2272_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2273_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2273_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2273_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2273_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2274_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2274_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2274_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2274_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2275_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2275_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2275_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2275_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2276_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2276_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2276_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2276_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2277_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2277_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2277_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2277_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2278_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2278_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2278_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2278_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2279_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2279_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2279_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2279_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2280_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2280_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2280_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2280_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2281_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2281_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2281_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2281_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2282_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2282_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2282_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2282_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2283_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2283_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2283_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2283_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2284_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2284_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2284_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2284_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2285_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2285_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2285_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2285_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2286_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2286_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2286_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2286_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2287_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2287_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2287_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2287_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2288_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2288_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2288_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2288_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2289_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2289_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2289_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2289_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2290_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2290_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2290_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2290_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2291_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2291_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2291_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2291_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2292_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2292_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2292_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2292_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2293_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2293_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2293_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2293_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2294_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2294_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2294_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2294_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2295_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2295_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2295_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2295_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2296_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2296_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2296_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2296_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2297_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2297_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2297_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2297_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2298_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2298_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2298_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2298_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2299_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2299_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2299_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2299_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2300_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2300_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2300_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2300_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2301_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2301_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2301_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2301_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2302_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2302_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2302_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2302_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2303_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2303_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2303_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2303_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2304_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2304_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2304_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2304_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2305_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2305_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2305_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2305_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2306_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2306_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2306_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2306_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2307_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2307_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2307_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2307_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2308_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2308_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2308_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2308_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2309_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2309_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2309_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2309_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2310_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2310_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2310_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2310_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2311_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2311_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2311_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2311_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2312_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2312_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2312_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2312_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2313_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2313_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2313_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2313_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2314_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2314_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2314_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2314_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2315_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2315_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2315_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2315_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2316_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2316_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2316_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2316_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2317_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2317_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2317_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2317_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2318_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2318_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2318_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2318_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2319_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2319_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2319_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2319_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2320_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2320_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2320_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2320_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2321_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2321_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2321_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2321_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2322_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2322_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2322_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2322_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2323_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2323_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2323_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2323_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2324_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2324_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2324_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2324_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2325_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2325_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2325_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2325_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2326_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2326_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2326_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2326_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2327_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2327_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2327_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2327_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2328_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2328_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2328_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2328_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2329_KTFE.jpg_clahe.jpg
#   inflating: Data/ThermalAug/T_Sad_2329_KTFE.jpg_flip.jpg
#   inflating: Data/ThermalAug/T_Sad_2329_KTFE.jpg_rotate15.jpg
#   inflating: Data/ThermalAug/T_Sad_2329_KTFE.jpg_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Sad_2330_KTFE.jpg_clahe.jpg
# ...
#   inflating: Data/ThermalAug/T_Surprised_77_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_77_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_77_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_782_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_782_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_782_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_782_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_783_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_783_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_783_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_783_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_784_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_784_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_784_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_784_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_785_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_785_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_785_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_785_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_786_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_786_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_786_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_786_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_787_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_787_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_787_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_787_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_788_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_788_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_788_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_788_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_789_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_789_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_789_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_789_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_790_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_790_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_790_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_790_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_791_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_791_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_791_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_791_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_792_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_792_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_792_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_792_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_7_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_7_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_7_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_7_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_815_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_815_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_815_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_815_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_816_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_816_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_816_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_816_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_817_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_817_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_817_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_817_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_818_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_818_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_818_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_818_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_819_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_819_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_819_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_819_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_820_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_820_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_820_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_820_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_821_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_821_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_821_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_821_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_822_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_822_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_822_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_822_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_823_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_823_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_823_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_823_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_824_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_824_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_824_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_824_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_825_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_825_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_825_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_825_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_848_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_848_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_848_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_848_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_849_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_849_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_849_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_849_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_850_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_850_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_850_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_850_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_851_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_851_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_851_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_851_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_852_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_852_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_852_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_852_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_853_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_853_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_853_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_853_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_854_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_854_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_854_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_854_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_855_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_855_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_855_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_855_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_856_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_856_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_856_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_856_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_857_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_857_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_857_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_857_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_858_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_858_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_858_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_858_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_881_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_881_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_881_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_881_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_882_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_882_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_882_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_882_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_883_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_883_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_883_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_883_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_884_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_884_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_884_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_884_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_885_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_885_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_885_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_885_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_886_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_886_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_886_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_886_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_887_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_887_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_887_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_887_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_888_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_888_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_888_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_888_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_889_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_889_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_889_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_889_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_890_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_890_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_890_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_890_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_891_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_891_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_891_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_891_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_8_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_8_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_8_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_8_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_914_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_914_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_914_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_914_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_915_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_915_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_915_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_915_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_916_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_916_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_916_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_916_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_917_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_917_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_917_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_917_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_918_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_918_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_918_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_918_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_919_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_919_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_919_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_919_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_920_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_920_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_920_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_920_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_921_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_921_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_921_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_921_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_922_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_922_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_922_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_922_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_923_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_923_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_923_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_923_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_924_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_924_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_924_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_924_IRIS.bmp_rotate15neg.jpg
#   inflating: Data/ThermalAug/T_Surprised_9_IRIS.bmp_clahe.jpg
#   inflating: Data/ThermalAug/T_Surprised_9_IRIS.bmp_flip.jpg
#   inflating: Data/ThermalAug/T_Surprised_9_IRIS.bmp_rotate15.jpg
#   inflating: Data/ThermalAug/T_Surprised_9_IRIS.bmp_rotate15neg.jpg

# %%
# !pip install -r requirements.txt

# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import json
import logging
from datetime import datetime
import wandb
from typing import Dict, List, Tuple, Optional, Union

from dataset import create_multimodal_data_loaders, MultiModalFERDataset
from model import create_multimodal_vit_model, get_optimizer_and_scheduler, ViTForFER, EarlyFusionViT, LateFusionViT
from utils import EarlyStopping, MetricsTracker, save_checkpoint, load_checkpoint, PerformanceAnalyzer

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)


class MultiModalFERTrainer:
    """
    Trainer class for Fine-tuning ViT on multimodal FER dataset
    Supports RGB-only, Thermal-only, and Combined (RGB+Thermal) modes
    """

    def __init__(
        self,
        model: Union[ViTForFER, EarlyFusionViT, LateFusionViT],
        train_loader: DataLoader,
        test_loader: DataLoader,
        optimizer: torch.optim.Optimizer,
        scheduler: torch.optim.lr_scheduler._LRScheduler,
        device: torch.device,
        config: Dict,
        mode: str = 'rgb',
        experiment_name: str = None
    ):
        self.model = model
        self.train_loader = train_loader
        self.test_loader = test_loader
        self.optimizer = optimizer
        self.scheduler = scheduler
        self.device = device
        self.config = config
        self.mode = mode.lower()

        # Setup experiment tracking
        self.experiment_name = experiment_name or f"multimodal_vit_fer_{self.mode}_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        self.save_dir = os.path.join(config['output_dir'], self.experiment_name)
        os.makedirs(self.save_dir, exist_ok=True)

        # Setup file logging
        self.setup_file_logging()

        # Initialise tracking
        self.tensorboard_writer = SummaryWriter(os.path.join(self.save_dir, 'tensorboard'))
        self.metrics_tracker = MetricsTracker()
        self.early_stopping = EarlyStopping(
            patience=config['early_stopping_patience'],
            min_delta=config['early_stopping_min_delta']
        )

        # Class names for metrics
        self.class_names = ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprised']

        # Initialise WandB if configured
        if config.get('use_wandb', False):
            wandb.init(
                project=config['wandb_project'],
                name=self.experiment_name,
                config=config
            )
            wandb.watch(self.model)

        # Loss function with class weights
        if config.get('use_class_weights', False):
            class_weights = self._get_class_weights()
            self.criterion = nn.CrossEntropyLoss(weight=class_weights)
        else:
            self.criterion = nn.CrossEntropyLoss()

        # File logger for training progress
        self.file_logger.info(f"Trainer initialized. Experiment: {self.experiment_name}")
        self.file_logger.info(f"Save directory: {self.save_dir}")
        self.file_logger.info(f"Training mode: {self.mode}")
        if self.mode == 'combined':
            self.file_logger.info(f"Fusion strategy: {config.get('fusion_strategy', 'early')}")
            self.file_logger.info(f"Fusion type: {config.get('fusion_type', 'concat')}")
            self.file_logger.info(f"Fusion layer: {config.get('fusion_layer', 'feature')}")
        self.file_logger.info(f"Training samples: {len(self.train_loader.dataset):,}")
        self.file_logger.info(f"Test samples: {len(self.test_loader.dataset):,}")
        self.file_logger.info(f"Use augmented data: {config.get('use_augmented', False)}")
        self.file_logger.info(f"Training configuration: {json.dumps(config, indent=2)}")

        logger.info(f"Trainer initialized. Experiment: {self.experiment_name}")
        logger.info(f"Save directory: {self.save_dir}")
        logger.info(f"Training mode: {self.mode}")

    def setup_file_logging(self):
        """Setup file logging for training progress"""
        log_file = os.path.join(self.save_dir, 'training_log.txt')

        # Create file logger
        self.file_logger = logging.getLogger(f'file_logger_{self.experiment_name}')
        self.file_logger.setLevel(logging.INFO)

        # Create file handler
        file_handler = logging.FileHandler(log_file)
        file_handler.setLevel(logging.INFO)

        # Create formatter
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        file_handler.setFormatter(formatter)

        # Add handler to logger
        self.file_logger.addHandler(file_handler)

    def _get_class_weights(self) -> torch.Tensor:
        """Calculate class weights for imbalanced dataset"""
        # Create a temporary dataset to get class weights
        temp_dataset = MultiModalFERDataset(
            data_dir=self.config['data_dir'],
            mode=self.mode,
            split_ratio=0.8,
            split_type='train',
            use_augmented=self.config.get('use_augmented', False)
        )
        class_weights = temp_dataset.get_class_weights().to(self.device)
        self.file_logger.info(f"Class weights: {class_weights}")
        return class_weights

    def train_epoch(self) -> Dict[str, float]:
        """Train for one epoch"""
        self.model.train()

        total_loss = 0
        predictions = []
        targets = []

        # Progress bar
        pbar = tqdm(self.train_loader, desc="Training")

        for batch_idx, batch in enumerate(pbar):
            # Handle different input formats based on mode
            if self.mode == 'combined':
                data, labels = batch
                rgb_images = data['rgb'].to(self.device)
                thermal_images = data['thermal'].to(self.device)
                labels = labels.to(self.device)

                # Forward pass for combined mode
                outputs = self.model(rgb_images, thermal_images, labels)
            else:
                # Single modality mode (RGB or Thermal)
                images, labels = batch
                images = images.to(self.device)
                labels = labels.to(self.device)

                # Forward pass for single modality
                outputs = self.model(images, labels)

            loss = outputs['loss']
            logits = outputs['logits']

            # Backward pass
            self.optimizer.zero_grad()
            loss.backward()

            # Gradient clipping
            if self.config.get('gradient_clip_norm', None):
                torch.nn.utils.clip_grad_norm_(
                    self.model.parameters(),
                    self.config['gradient_clip_norm']
                )

            self.optimizer.step()
            self.scheduler.step()

            # Track metrics
            total_loss += loss.item()
            predictions.extend(torch.argmax(logits, dim=1).cpu().numpy())
            targets.extend(labels.cpu().numpy())

            # Update progress bar
            pbar.set_postfix({
                'Loss': f'{loss.item():.4f}',
                'LR': f'{self.scheduler.get_last_lr()[0]:.6f}'
            })

        # Calculate epoch metrics
        epoch_loss = total_loss / len(self.train_loader)
        epoch_acc = accuracy_score(targets, predictions)
        epoch_f1 = f1_score(targets, predictions, average='weighted')

        metrics = {
            'loss': epoch_loss,
            'accuracy': epoch_acc,
            'f1_score': epoch_f1,
            'precision': precision_score(targets, predictions, average='weighted'),
            'recall': recall_score(targets, predictions, average='weighted')
        }

        return metrics

    def validate_epoch(self, loader: DataLoader) -> Dict[str, float]:
        """Validate for one epoch"""
        self.model.eval()

        total_loss = 0
        predictions = []
        targets = []

        with torch.no_grad():
            for batch in tqdm(loader, desc="Validating"):
                # Handle different input formats based on mode
                if self.mode == 'combined':
                    data, labels = batch
                    rgb_images = data['rgb'].to(self.device)
                    thermal_images = data['thermal'].to(self.device)
                    labels = labels.to(self.device)

                    # Forward pass for combined mode
                    outputs = self.model(rgb_images, thermal_images, labels)
                else:
                    # Single modality mode (RGB or Thermal)
                    images, labels = batch
                    images = images.to(self.device)
                    labels = labels.to(self.device)

                    # Forward pass for single modality
                    outputs = self.model(images, labels)

                loss = outputs['loss']
                logits = outputs['logits']

                # Track metrics
                total_loss += loss.item()
                predictions.extend(torch.argmax(logits, dim=1).cpu().numpy())
                targets.extend(labels.cpu().numpy())

        # Calculate epoch metrics
        epoch_loss = total_loss / len(loader)
        epoch_acc = accuracy_score(targets, predictions)
        epoch_f1 = f1_score(targets, predictions, average='weighted')

        metrics = {
            'loss': epoch_loss,
            'accuracy': epoch_acc,
            'f1_score': epoch_f1,
            'precision': precision_score(targets, predictions, average='weighted'),
            'recall': recall_score(targets, predictions, average='weighted'),
            'predictions': predictions,
            'targets': targets
        }

        return metrics

    def train(self, num_epochs: int) -> Dict:
        """Main training loop"""
        self.file_logger.info(f"Starting training for {num_epochs} epochs")
        logger.info(f"Starting training for {num_epochs} epochs")

        best_f1 = 0.0

        for epoch in range(num_epochs):
            self.file_logger.info(f"\n=== Epoch {epoch + 1}/{num_epochs} ===")
            logger.info(f"\n=== Epoch {epoch + 1}/{num_epochs} ===")

            # Training phase
            train_metrics = self.train_epoch()

            # Validation phase on test set (since we don't have separate validation)
            val_metrics = self.validate_epoch(self.test_loader)

            # Log metrics
            self._log_metrics(epoch, train_metrics, val_metrics)

            # Track metrics
            self.metrics_tracker.update(
                epoch + 1,
                {
                    'loss': train_metrics['loss'],
                    'accuracy': train_metrics['accuracy'],
                    'f1': train_metrics['f1_score'],
                    'precision': train_metrics['precision'],
                    'recall': train_metrics['recall']
                },
                {
                    'loss': val_metrics['loss'],
                    'accuracy': val_metrics['accuracy'],
                    'f1': val_metrics['f1_score'],
                    'precision': val_metrics['precision'],
                    'recall': val_metrics['recall']
                }
            )

            # Check for best model (based on validation F1 score)
            if val_metrics['f1_score'] > best_f1:
                best_f1 = val_metrics['f1_score']
                self._save_checkpoint('best_model.pth', epoch, val_metrics)
                self.file_logger.info(f"New best model saved with F1: {best_f1:.4f}")

            # Early stopping check
            if self.early_stopping(val_metrics['loss']):
                self.file_logger.info(f"Early stopping triggered at epoch {epoch + 1}")
                logger.info(f"Early stopping triggered at epoch {epoch + 1}")
                break

        # Save final model
        self._save_checkpoint('last_model.pth', epoch, val_metrics)

        # Generate final results
        final_results = self._generate_final_results(val_metrics)

        # Close logging
        self.tensorboard_writer.close()

        if self.config.get('use_wandb', False):
            wandb.finish()

        self.file_logger.info("Training completed!")
        logger.info("Training completed!")

        return final_results

    def _log_metrics(self, epoch: int, train_metrics: Dict, val_metrics: Dict):
        """Log metrics to various tracking systems"""
        # Console logging
        logger.info(f"Train - Loss: {train_metrics['loss']:.4f}, "
                   f"Acc: {train_metrics['accuracy']:.4f}, "
                   f"F1: {train_metrics['f1_score']:.4f}")
        logger.info(f"Val   - Loss: {val_metrics['loss']:.4f}, "
                   f"Acc: {val_metrics['accuracy']:.4f}, "
                   f"F1: {val_metrics['f1_score']:.4f}")

        # File logging
        self.file_logger.info(f"Train - Loss: {train_metrics['loss']:.4f}, "
                             f"Acc: {train_metrics['accuracy']:.4f}, "
                             f"F1: {train_metrics['f1_score']:.4f}, "
                             f"Precision: {train_metrics['precision']:.4f}, "
                             f"Recall: {train_metrics['recall']:.4f}")
        self.file_logger.info(f"Val   - Loss: {val_metrics['loss']:.4f}, "
                             f"Acc: {val_metrics['accuracy']:.4f}, "
                             f"F1: {val_metrics['f1_score']:.4f}, "
                             f"Precision: {val_metrics['precision']:.4f}, "
                             f"Recall: {val_metrics['recall']:.4f}")

        # TensorBoard logging
        self.tensorboard_writer.add_scalars('Loss', {
            'Train': train_metrics['loss'],
            'Val': val_metrics['loss']
        }, epoch)

        self.tensorboard_writer.add_scalars('Accuracy', {
            'Train': train_metrics['accuracy'],
            'Val': val_metrics['accuracy']
        }, epoch)

        self.tensorboard_writer.add_scalars('F1 Score', {
            'Train': train_metrics['f1_score'],
            'Val': val_metrics['f1_score']
        }, epoch)

        # WandB logging
        if self.config.get('use_wandb', False):
            wandb.log({
                'epoch': epoch,
                'train_loss': train_metrics['loss'],
                'val_loss': val_metrics['loss'],
                'train_accuracy': train_metrics['accuracy'],
                'val_accuracy': val_metrics['accuracy'],
                'train_f1': train_metrics['f1_score'],
                'val_f1': val_metrics['f1_score'],
                'learning_rate': self.scheduler.get_last_lr()[0]
            })

    def _save_checkpoint(self, filename: str, epoch: int, metrics: Dict):
        """Save model checkpoint"""
        checkpoint = {
            'epoch': epoch,
            'model_state_dict': self.model.state_dict(),
            'optimizer_state_dict': self.optimizer.state_dict(),
            'scheduler_state_dict': self.scheduler.state_dict(),
            'metrics': metrics,
            'config': self.config,
            'mode': self.mode
        }

        save_path = os.path.join(self.save_dir, filename)
        torch.save(checkpoint, save_path)
        self.file_logger.info(f"Checkpoint saved: {save_path}")

    def _generate_final_results(self, final_metrics: Dict) -> Dict:
        """Generate and save final results with detailed evaluation metrics"""
        # Create performance analyzer
        analyzer = PerformanceAnalyzer(self.class_names)

        # Generate comprehensive analysis
        detailed_analysis = analyzer.generate_detailed_analysis(
            final_metrics['targets'],
            final_metrics['predictions'],
            self.save_dir
        )

        # Calculate additional metrics
        from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

        # Overall metrics
        overall_accuracy = accuracy_score(final_metrics['targets'], final_metrics['predictions'])

        # Macro and Micro averages
        macro_f1 = f1_score(final_metrics['targets'], final_metrics['predictions'], average='macro')
        micro_f1 = f1_score(final_metrics['targets'], final_metrics['predictions'], average='micro')
        macro_precision = precision_score(final_metrics['targets'], final_metrics['predictions'], average='macro')
        micro_precision = precision_score(final_metrics['targets'], final_metrics['predictions'], average='micro')
        macro_recall = recall_score(final_metrics['targets'], final_metrics['predictions'], average='macro')
        micro_recall = recall_score(final_metrics['targets'], final_metrics['predictions'], average='micro')

        # Per-class accuracy
        per_class_accuracy = []
        cm = confusion_matrix(final_metrics['targets'], final_metrics['predictions'])
        for i in range(len(self.class_names)):
            if cm[i, :].sum() > 0:
                class_accuracy = cm[i, i] / cm[i, :].sum()
            else:
                class_accuracy = 0.0
            per_class_accuracy.append(class_accuracy)

        # Create comprehensive results dictionary
        results = {
            'mode': self.mode,
            'experiment_name': self.experiment_name,
            'final_metrics': {
                'overall_accuracy': float(overall_accuracy),
                'weighted_f1_score': float(final_metrics['f1_score']),
                'weighted_precision': float(final_metrics['precision']),
                'weighted_recall': float(final_metrics['recall']),
                'macro_f1_score': float(macro_f1),
                'micro_f1_score': float(micro_f1),
                'macro_precision': float(macro_precision),
                'micro_precision': float(micro_precision),
                'macro_recall': float(macro_recall),
                'micro_recall': float(micro_recall)
            },
            'per_class_metrics': {
                'classes': self.class_names,
                'accuracy': per_class_accuracy,
                'f1_scores': detailed_analysis['class_performance'][self.class_names[0]]['f1_score'] if self.class_names else [],
                'precision': [detailed_analysis['class_performance'][class_name]['precision'] for class_name in self.class_names],
                'recall': [detailed_analysis['class_performance'][class_name]['recall'] for class_name in self.class_names]
            },
            'confusion_matrix': cm.tolist(),
            'training_history': self.metrics_tracker.get_history(),
            'detailed_analysis': detailed_analysis
        }

        # Fix per-class F1 scores extraction
        results['per_class_metrics']['f1_scores'] = [
            detailed_analysis['class_performance'][class_name]['f1_score']
            for class_name in self.class_names
        ]

        # Save comprehensive results
        results_file = os.path.join(self.save_dir, 'final_results.json')
        with open(results_file, 'w') as f:
            json.dump(results, f, indent=2)

        # Save evaluation summary
        evaluation_summary = {
            'experiment_name': self.experiment_name,
            'mode': self.mode,
            'overall_accuracy': float(overall_accuracy),
            'macro_f1_score': float(macro_f1),
            'micro_f1_score': float(micro_f1),
            'weighted_f1_score': float(final_metrics['f1_score']),
            'per_class_accuracy': {
                class_name: float(acc) for class_name, acc in zip(self.class_names, per_class_accuracy)
            }
        }

        summary_file = os.path.join(self.save_dir, 'evaluation_summary.json')
        with open(summary_file, 'w') as f:
            json.dump(evaluation_summary, f, indent=2)

        # Plot training history
        self.metrics_tracker.plot_metrics(self.save_dir)

        # Log detailed results
        self.file_logger.info("=== DETAILED EVALUATION RESULTS ===")
        self.file_logger.info(f"Overall Accuracy: {overall_accuracy:.4f}")
        self.file_logger.info(f"Macro F1-Score: {macro_f1:.4f}")
        self.file_logger.info(f"Micro F1-Score: {micro_f1:.4f}")
        self.file_logger.info(f"Weighted F1-Score: {final_metrics['f1_score']:.4f}")
        self.file_logger.info("Per-class Accuracy:")
        for class_name, acc in zip(self.class_names, per_class_accuracy):
            self.file_logger.info(f"  {class_name}: {acc:.4f}")
        self.file_logger.info("Final evaluation completed with comprehensive metrics")

        return results


def main(data_dir):
    """Main training function"""
    # Configuration
    config = {
        'data_dir': data_dir,
        'output_dir': './experiments',
        'mode': 'rgb',  # 'rgb', 'thermal', or 'combined'
        'fusion_strategy': 'early',  # 'early' or 'late' (for combined mode)
        'fusion_type': 'concat',  # 'concat', 'add', or 'attention'
        'fusion_layer': 'feature',  # 'feature' or 'prediction' (for late fusion)

        # Model parameters
        'model_name': 'google/vit-base-patch16-224-in21k',
        'num_classes': 7,
        'dropout_rate': 0.1,
        'freeze_backbone': False,
        'use_gradient_checkpointing': False,

        # Training parameters
        'batch_size': 32,
        'num_epochs': 30,
        'learning_rate': 5e-5,
        'weight_decay': 0.01,
        'warmup_steps': 500,
        'gradient_clip_norm': 1.0,

        # Data parameters
        'image_size': 224,
        'num_workers': 4,
        'val_split': 0.2,
        'use_augmented': True,
        'use_class_weights': True,

        # Early stopping
        'early_stopping_patience': 10,
        'early_stopping_min_delta': 0.001,

        # Logging
        'use_wandb': False,
        'wandb_project': 'multimodal-fer'
    }

    # Device setup
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    logger.info(f"Using device: {device}")

    # Create data loaders
    logger.info("Creating data loaders...")
    train_loader, test_loader = create_multimodal_data_loaders(
        data_dir=config['data_dir'],
        mode=config['mode'],
        batch_size=config['batch_size'],
        image_size=config['image_size'],
        num_workers=config['num_workers'],
        val_split=config['val_split'],
        use_augmented=config['use_augmented']
    )

    # Log dataset information
    train_samples = len(train_loader.dataset)
    test_samples = len(test_loader.dataset)
    logger.info(f"=== DATASET INFORMATION ===")
    logger.info(f"Training Mode: {config['mode'].upper()}")
    if config['mode'] == 'combined':
        logger.info(f"Fusion Strategy: {config['fusion_strategy']}")
        logger.info(f"Fusion Type: {config['fusion_type']}")
        logger.info(f"Fusion Layer: {config['fusion_layer']}")
    logger.info(f"Use Augmented Data: {config['use_augmented']}")
    logger.info(f"Training Samples: {train_samples:,}")
    logger.info(f"Test Samples: {test_samples:,}")
    logger.info(f"Train Batches: {len(train_loader)}, Test Batches: {len(test_loader)}")
    logger.info(f"Batch Size: {config['batch_size']}")

    # Create model
    logger.info("Creating model...")
    model = create_multimodal_vit_model(
        mode=config['mode'],
        fusion_strategy=config['fusion_strategy'],
        fusion_type=config['fusion_type'],
        fusion_layer=config['fusion_layer'],
        model_name=config['model_name'],
        num_classes=config['num_classes'],
        dropout_rate=config['dropout_rate'],
        freeze_backbone=config['freeze_backbone'],
        use_gradient_checkpointing=config['use_gradient_checkpointing']
    )

    model.to(device)

    # Calculate total training steps
    total_steps = len(train_loader) * config['num_epochs']

    # Create optimizer and scheduler
    optimizer, scheduler = get_optimizer_and_scheduler(
        model=model,
        learning_rate=config['learning_rate'],
        weight_decay=config['weight_decay'],
        warmup_steps=config['warmup_steps'],
        num_training_steps=total_steps
    )

    # Create trainer
    trainer = MultiModalFERTrainer(
        model=model,
        train_loader=train_loader,
        test_loader=test_loader,
        optimizer=optimizer,
        scheduler=scheduler,
        device=device,
        config=config,
        mode=config['mode']
    )

    # Start training
    logger.info("Starting training...")
    results = trainer.train(config['num_epochs'])

    # Print final results
    logger.info("Training completed!")

# %%
"""Main training execution command
   Edit the config dictionary in main() to customise training parameters
   rgb, thermal, combined modes are available
   early and late fusion strategies are available for combined
"""
data_dir = 'Data'
main(data_dir)

# %% [markdown]
# **Inference**

# %%
import os
from inference import MultiModalFERInference
# Load model
print(f"Loading model...")
inferencer = MultiModalFERInference('experiments/multimodal_vit_fer_rgb_20250706_124950/best_model.pth')
print(f"✓ Model loaded successfully!")
print(f"Mode: {inferencer.mode}")

# %%
# Run inference
print(f"\nRunning inference...")
result = inferencer.predict_single('Data/RGB/R_Angry_1_KTFE.jpg', 'Data/Thermal/R_Angry_1_KTFE.jpg')

# Display results
print("\n" + "="*60)
print("🎭 EMOTION RECOGNITION RESULT")
print("="*60)
print(f"📊 Model Mode: {result['mode'].upper()}")
print(f"😊 Predicted Emotion: {result['predicted_class'].upper()}")
print(f"🎯 Confidence: {result['confidence_percent']:.1f}%")

print(f"\n🏆 Top 3 Predictions:")
for i, pred in enumerate(result['top3_predictions'], 1):
    emoji = "🥇" if i == 1 else "🥈" if i == 2 else "🥉"
    print(f"   {emoji} {pred['class']}: {pred['confidence']:.1f}%")

print(f"\n📈 All Emotion Probabilities:")
for emotion, prob in result['all_probabilities'].items():
    bar_length = int(prob * 20)  # Scale to 20 chars
    bar = "█" * bar_length + "░" * (20 - bar_length)
    print(f"   {emotion:>10}: {bar} {prob*100:5.1f}%")
